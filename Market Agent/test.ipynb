# %%
import yfinance as yf
import matplotlib.pyplot as mp

# %%
COMMODITIES = yf.Market("COMMODITIES")

status= COMMODITIES.status
summary = COMMODITIES.summary
# Out:
# COMMODITIES: Failed to update market status

# %%
yf.Ticker("CL=F").history(period="5y")
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2021-02-12 00:00:00-05:00  57.939999  59.820000  57.410000  59.470001  480822
# 2021-02-16 00:00:00-05:00  59.980000  60.950001  59.330002  60.049999  602332
# 2021-02-17 00:00:00-05:00  60.240002  61.730000  59.430000  61.139999  335419
# 2021-02-18 00:00:00-05:00  61.680000  62.259998  59.790001  60.520000  132035
# 2021-02-19 00:00:00-05:00  60.200001  60.290001  58.590000  59.240002  102427
# ...                              ...        ...        ...        ...     ...
# 2026-02-06 00:00:00-05:00  63.099998  64.580002  62.200001  63.549999  448924
# 2026-02-09 00:00:00-05:00  62.990002  64.879997  62.619999  64.360001  298005
# 2026-02-10 00:00:00-05:00  64.440002  64.709999  63.650002  63.959999  276292
# 2026-02-11 00:00:00-05:00  64.199997  65.830002  64.150002  64.629997  276292
# 2026-02-12 00:00:00-05:00  64.870003  65.099998  62.540001  62.779999  191830
#
# ...

# %%
oil_data = yf.Ticker("CL=F").history(period="5y")[
    'Close'].resample('W').mean().iloc[:104]

# %%
mp.figure(figsize=(12, 6))
mp.plot(oil_data.index, oil_data.values, label='Oil Price (CL=F)', color='blue')
