# %%
import pandas as pd
import matplotlib.pyplot as mp

# %%
df = pd.read_csv("all_paths.csv", header=None)
df.head(20)
# Out:
#       0         1         2         3         4         5         6   \
# 0   0.25  0.246969  0.255003  0.251152  0.256352  0.266183  0.253393
# 1   0.25  0.237107  0.269476  0.284219  0.236014  0.230719  0.221026
# 2   0.25  0.255902  0.207848  0.192020  0.196363  0.192627  0.142967
# 3   0.25  0.247540  0.269602  0.271653  0.310114  0.290808  0.289695
# 4   0.25  0.267406  0.264286  0.320339  0.307747  0.302158  0.226486
# 5   0.25  0.241461  0.270797  0.312497  0.343560  0.309502  0.350572
# 6   0.25  0.190220  0.172223  0.158871  0.166486  0.156022  0.135393
# 7   0.25  0.263161  0.208162  0.181598  0.165734  0.165418  0.141098
# 8   0.25  0.288935  0.293988  0.406301  0.434287  0.360298  0.284228
# 9   0.25  0.239045  0.200056  0.219783  0.192648  0.220714  0.217759
# 10  0.25  0.188966  0.166020  0.160246  0.184344  0.237195  0.290728
# 11  0.25  0.200152  0.218937  0.188201  0.198708  0.188297  0.226993
# 12  0.25  0.318888  0.269947  0.323101  0.346613  0.324167  0.375193
# ...

# %%
mp.figure(figsize=(20, 10))
        
for i in range(len(df)):
    mp.plot(df.iloc[i], color='blue')
    
mean_path = df.mean(axis=0)
mp.plot(mean_path, color='red', linewidth=2, label='Mean Forecasted Balance')

mp.title('Monte Carlo GBM Forecast (60 Days)')
mp.xlabel('Days into the Future')
mp.ylabel('Projected Balance (£)')
mp.grid(True, alpha=0.3)
mp.legend()
mp.tight_layout()
